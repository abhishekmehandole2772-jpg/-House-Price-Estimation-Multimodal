# %%
import pandas as pd

# %%
df = pd.read_csv("C:\GITHUB\Learning-tasks\students\Abishek\Machine Learning\House-Price-Estimation-Multimodal\House Price India.csv")

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.461900e+04  14619.000000        14619.000000         14619.000000
# mean   6.762821e+09  42604.546412            3.379233             2.129557
# std    6.237162e+03     67.343747            0.938655             0.769955
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14619.000000  1.461900e+04      14619.000000        14619.000000
# mean    2098.156851  1.509369e+04          1.502326            0.007661
# std      928.218740  3.792089e+04          0.540241            0.087196
# ...

# %%
df["Price"].describe()
# Out:
# count    1.461900e+04
# mean     5.388063e+05
# std      3.672294e+05
# min      7.800000e+04
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Price, dtype: float64

# %%
df["Price"].describe().reset_index()
# Out:
#    index         Price
# 0  count  1.461900e+04
# 1   mean  5.388063e+05
# 2    std  3.672294e+05
# 3    min  7.800000e+04
# 4    25%  3.200000e+05
# 5    50%  4.500000e+05
# 6    75%  6.450000e+05
# 7    max  7.700000e+06

# %%
stats = df["Price"].describe().reset_index()
stats["Price"] = round(stats["Price"],2)
stats
# Out:
#    index       Price
# 0  count    14619.00
# 1   mean   538806.28
# 2    std   367229.36
# 3    min    78000.00
# 4    25%   320000.00
# 5    50%   450000.00
# 6    75%   645000.00
# 7    max  7700000.00

# %%
df["Price"].describe().reset_index()["Price"]
# Out:
# 0    1.461900e+04
# 1    5.388063e+05
# 2    3.672294e+05
# 3    7.800000e+04
# 4    3.200000e+05
# 5    4.500000e+05
# 6    6.450000e+05
# 7    7.700000e+06
# Name: Price, dtype: float64

# %%
round(df["Price"].describe().reset_index()["Price"],2)
# Out:
# 0      14619.00
# 1     538806.28
# 2     367229.36
# 3      78000.00
# 4     320000.00
# 5     450000.00
# 6     645000.00
# 7    7700000.00
# Name: Price, dtype: float64

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# for na values
df.dropna(inplace = True)
# for duplicated values
df.drop_duplicates(inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df.groupby("condition of the house")["Price"].mean()
# Out:
# condition of the house
# 1    285497.222222
# 2    312891.400000
# 3    539336.477968
# 4    521082.494579
# 5    609954.024276
# Name: Price, dtype: float64

# %%
df.groupby("condition of the house")["Price"].mean().sort_values(ascending=False)
# Out:
# condition of the house
# 5    609954.024276
# 3    539336.477968
# 4    521082.494579
# 2    312891.400000
# 1    285497.222222
# Name: Price, dtype: float64

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
df.groupby("condition of the house")["Price"].mean().sort_values(ascending=False).plot(kind="bar",  colormap="viridis" )
plt.title("Average House Price by Condition")
plt.xlabel("Condition of the House")
plt.ylabel("Average Price")
plt.xticks(rotation=360) # Tilts labels for better readability
plt.show()

# %%
# Assuming you have 5 categories
colors = ['red', 'blue', 'green', 'orange', 'purple']
df.groupby("condition of the house")["Price"].mean().sort_values(ascending=False).plot(kind="bar",  color=colors)
# Out:
# <Axes: xlabel='condition of the house'>

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df[["number of bedrooms", "number of bathrooms"]]
# Out:
#        number of bedrooms  number of bathrooms
# 0                       4                 2.50
# 1                       5                 2.75
# 2                       4                 2.50
# 3                       3                 2.00
# 4                       3                 2.50
# ...                   ...                  ...
# 14614                   2                 1.50
# 14615                   3                 2.00
# 14616                   2                 1.00
# 14617                   4                 1.00
# 14618                   3                 1.00
#
# [14619 rows x 2 columns]

# %%
X = df[['number of bedrooms', 'number of bathrooms','living area','condition of the house','Number of schools nearby' ]]
Y = df[['Price']]

# %%
X
# Out:
#        number of bedrooms  number of bathrooms  living area  \
# 0                       4                 2.50         2920
# 1                       5                 2.75         2910
# 2                       4                 2.50         3310
# 3                       3                 2.00         2710
# 4                       3                 2.50         2600
# ...                   ...                  ...          ...
# 14614                   2                 1.50         1556
# 14615                   3                 2.00         1680
# 14616                   2                 1.00         1070
# 14617                   4                 1.00         1030
# 14618                   3                 1.00          900
#
#        condition of the house  Number of schools nearby
# 0                           5                         2
# 1                           3                         1
# 2                           3                         3
# ...

# %%
Y
# Out:
#          Price
# 0      1400000
# 1      1200000
# 2       838000
# 3       805000
# 4       790000
# ...        ...
# 14614   221700
# 14615   219200
# 14616   209000
# 14617   205000
# 14618   146000
#
# [14619 rows x 1 columns]

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,  test_size= 0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 1. Initialize the model
model = LinearRegression()

# 2. Train the model (Fitting)
model.fit(X_train, y_train)

# 3. Make predictions on the test set
predictions = model.predict(X_test)

# 4. Check the performance
print(f"R^2 Score: {r2_score(y_test, predictions)}")
print(f"MSE: {mean_squared_error(y_test, predictions)}")
# Out:
# R^2 Score: 0.5438195157393122
# MSE: 66123824665.21267

# %%
df.shape[0] * 0.8
# Out:
# 11695.2

# %%
df.shape[0] * 0.2
# Out:
# 2923.8

# %%
X_train.shape
# Out:
# (11695, 5)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# 1. Define the parameters to test
param_grid = {
    "criterion": ["squared_error", "friedman_mse", "absolute_error"],
    "splitter" : ["best", "random"],
    "max_depth" : [None, 10, 20, 30, 40, 50],
    "min_samples_split" : [2, 5, 10],
    "min_samples_leaf" : [1, 2, 4]
}

# 2. Initialize the model
tree_model = DecisionTreeRegressor()

# 3. Setup the Grid Search
# This will try every combination of parameters defined above
grid_tree = GridSearchCV(estimator=tree_model, param_grid=param_grid)

# 4. Train the models on your training data
grid_tree.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
 tree_preds = grid_tree.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# 1. Predict using the GridSearch Decision Tree
tree_preds = grid_tree.predict(X_test)

# 2. Evaluate Decision Tree performance
mse_tree = mean_absolute_error(y_test, tree_preds)
print(mse_tree)

# 3. Initialize and train a Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)

# 4. Make predictions with Linear Regression
predslr = lr.predict(X_test)
# Out:
# 162797.94276710626

# %%
mean_absolute_error(y_test,predslr)
# Out:
# 164364.3225756088

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Initialize the model
rfrmodel = RandomForestRegressor()

# Define the parameter grid
param_gridrfr = {
    "max_depth": [5, 10, 15],
    "n_estimators": [2, 3, 4, 5, 6, 7, 8, 9, 10]
}

# Setup GridSearchCV
gridrfr = GridSearchCV(rfrmodel, param_gridrfr)

# Fit the model to find the best parameters
gridrfr.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6, 7, 8, 9, 10]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 7}

# %%
import joblib
from sklearn.metrics import mean_absolute_error

# 1. Generate final predictions using the tuned Random Forest
rfrpredictions = gridrfr.predict(X_test)

# 2. Calculate the Mean Absolute Error
# This tells you, on average, how many dollars off your price predictions are
error = mean_absolute_error(y_test, rfrpredictions)
print(error)

# 3. View the model object structure
gridrfr

# 4. Save (serialize) your model to a file named 'model.pkl'
joblib.dump(gridrfr, "model.pkl")
# Out:
# 159009.38514653928
# ['model.pkl']

# %%
X.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area',
#        'condition of the house', 'Number of schools nearby'],
#       dtype='object')

# %%
import os
os.getcwd()
# Out:
# 'c:\\GITHUB\\Learning-tasks\\students\\Abishek\\Machine Learning\\House-Price-Estimation-Multimodal'
